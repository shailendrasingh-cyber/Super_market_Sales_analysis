# %%
import pandas as pd 
import matplotlib.pyplot  as plt 
import numpy as np 
import seaborn as sns

# %%
#load the dataset

# %%
df =  pd.read_csv("supermarket_sales - Sheet1.csv")

# %%
# checking the top 5 rows of the data set

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
# checking last 5 rows of the data set

# %%
df.tail()
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time  Payment  \
# 995       40.35         1   2.0175    42.3675  1/29/2019  13:46  Ewallet
# 996       97.38        10  48.6900  1022.4900   3/2/2019  17:16  Ewallet
# 997       31.84         1   1.5920    33.4320   2/9/2019  13:22     Cash
# 998       65.82         1   3.2910    69.1110  2/22/2019  15:33     Cash
# 999       88.34         7  30.9190   649.2990  2/18/2019  13:28     Cash
#
# ...

# %%
# checking the number of rows and columns in data set

# %%
print("Number of rows are " , df.shape[0])
print("Number of columns are " , df.shape[1])
# Out:
# Number of rows are  1000
# Number of columns are  17

# %%
# checking the null values in data set

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
# so as we see there are not any null value are present in our dataset

# %%
# checking the data type of each columns

# %%
df.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %%
df.head(1)
# Out:
#     Invoice ID Branch    City Customer type  Gender       Product line  \
# 0  750-67-8428      A  Yangon        Member  Female  Health and beauty
#
#    Unit price  Quantity   Tax 5%     Total      Date   Time  Payment    cogs  \
# 0       74.69         7  26.1415  548.9715  1/5/2019  13:08  Ewallet  522.83
#
#    gross margin percentage  gross income  Rating
# 0                 4.761905       26.1415     9.1

# %%
# stats of dataset

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
# dropping the columns which are not useful for data analysis

# %%
df.head(2)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total      Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715  1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200  3/8/2019
#
#     Time  Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08  Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29     Cash   76.40                 4.761905        3.8200     9.6

# %%
# list of the  columns that are being dropped 
# invoice id 
# gross margin percentage 
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df=df.drop(['gross margin percentage' , 'Invoice ID'] , axis=1)

# %%
df.head()
# Out:
#   Branch       City Customer type  Gender            Product line  Unit price  \
# 0      A     Yangon        Member  Female       Health and beauty       74.69
# 1      C  Naypyitaw        Normal  Female  Electronic accessories       15.28
# 2      A     Yangon        Normal    Male      Home and lifestyle       46.33
# 3      A     Yangon        Member    Male       Health and beauty       58.22
# 4      A     Yangon        Normal    Male       Sports and travel       86.31
#
#    Quantity   Tax 5%     Total       Date   Time      Payment    cogs  \
# 0         7  26.1415  548.9715   1/5/2019  13:08      Ewallet  522.83
# 1         5   3.8200   80.2200   3/8/2019  10:29         Cash   76.40
# 2         7  16.2155  340.5255   3/3/2019  13:23  Credit card  324.31
# 3         8  23.2880  489.0480  1/27/2019  20:33      Ewallet  465.76
# 4         7  30.2085  634.3785   2/8/2019  10:37      Ewallet  604.17
#
#    gross income  Rating
# 0       26.1415     9.1
# 1        3.8200     9.6
# ...

# %%
# find out date and time when cpmpany earn maximum profit

# %%
df['gross income'].max()
# Out:
# 49.65

# %%
df[df['gross income']==49.65]
# Out:
#     Branch       City Customer type  Gender         Product line  Unit price  \
# 350      C  Naypyitaw        Member  Female  Fashion accessories        99.3
#
#      Quantity  Tax 5%    Total       Date   Time      Payment   cogs  \
# 350        10   49.65  1042.65  2/15/2019  14:53  Credit card  993.0
#
#      gross income  Rating
# 350         49.65     6.6

# %%
# on which product line we earn min

# %%
df['Total'].min()
# Out:
# 10.6785

# %%
df[df['Total']==10.6785]
# Out:
#     Branch       City Customer type Gender       Product line  Unit price  \
# 822      C  Naypyitaw        Member   Male  Sports and travel       10.17
#
#      Quantity  Tax 5%    Total      Date   Time Payment   cogs  gross income  \
# 822         1  0.5085  10.6785  2/7/2019  14:15    Cash  10.17        0.5085
#
#      Rating
# 822     5.9

# %%
# lets see both distribution of single variables and relationships between two variables
# for this we use pairplot of seaborn library

# %%
sns.pairplot(df)

# %%
# Visualizing the data 
df.columns
# Out:
# Index(['Branch', 'City', 'Customer type', 'Gender', 'Product line',
#        'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date', 'Time', 'Payment',
#        'cogs', 'gross income', 'Rating'],
#       dtype='object')

# %%
sns.barplot(data=df ,x='City' , y='Total').set(title='Total income on City')
df['City'].value_counts()
# Out:
# Yangon       340
# Mandalay     332
# Naypyitaw    328
# Name: City, dtype: int64

# %%
#As we see that Naypyitaw City Earn more

# %%
# Find out which Product line has more margin 
df.columns
# Out:
# Index(['Branch', 'City', 'Customer type', 'Gender', 'Product line',
#        'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date', 'Time', 'Payment',
#        'cogs', 'gross income', 'Rating'],
#       dtype='object')

# %%
fig, ax = plt.subplots(figsize=(8, 8))
plot=sns.barplot(data=df,  x="Product line", y="gross income" , ax=ax)
plt.setp(plot.get_xticklabels(), rotation=90)
plot.bar_label(ax.containers[0], label_type='edge', padding=50)
# Out:
# [Text(0, 50, '15.4116'),
#  Text(0, 50, '15.2206'),
#  Text(0, 50, '16.0303'),
#  Text(0, 50, '15.8126'),
#  Text(0, 50, '15.3653'),
#  Text(0, 50, '14.5281')]

# %% [markdown]
# so from home and lifstyle company earn more margin as compared to other product line but one thing was comman that
# the margin rate was start from 14 and end to 16.5

# %%
df.columns
# Out:
# Index(['Branch', 'City', 'Customer type', 'Gender', 'Product line',
#        'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date', 'Time', 'Payment',
#        'cogs', 'gross income', 'Rating'],
#       dtype='object')

# %%
# Total sale wrt to Branch

# %%
fig, ax = plt.subplots(figsize=(10, 9))
plot = sns.barplot(x='Branch' , y ='Total' , data=df)
plt.setp(plot.get_xticklabels(), rotation=25)
plot.bar_label(ax.containers[0], label_type='edge', padding=45)
# Out:
# [Text(0, 45, '312.354'), Text(0, 45, '337.1'), Text(0, 45, '319.873')]

# %% [markdown]
# So the sale in C brach was pretty high as compare to A and B branch

# %%
df.columns
# Out:
# Index(['Branch', 'City', 'Customer type', 'Gender', 'Product line',
#        'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date', 'Time', 'Payment',
#        'cogs', 'gross income', 'Rating'],
#       dtype='object')

# %% [markdown]
# which payment mode is more famous
# fig, ax = plt.subplots(figsize=(10, 9))
# plot = sns.barplot(x='Branch' , y ='Total' , data=df)
# plt.setp(plot.get_xticklabels(), rotation=25)
# plot.bar_label(ax.containers[0], label_type='edge', padding=45)

# %%
fig,ax=plt.subplots(figsize=(10,6))
plot =  sns.barplot(x='Payment' , y='Total' , data=df)
plt.setp(plot.get_xticklabels(), r
# Out:
#   Input In [41]
#     plt.setp(plot.get_xticklabels(), r
#                                       ^
# SyntaxError: unexpected EOF while parsing

# %%
df.Date.head(34)

# %%
df.Date.tail()

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df['Month']=df['Date'].dt.month

# %%
df
